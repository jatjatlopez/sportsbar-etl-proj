# %%
customer_notebooks = [
    "/Users/lopezjatjat10@gmail.com/sportsbar-etl-proj/2_dim_data_process/bronze/bronze_customer_data_processing",
    "/Users/lopezjatjat10@gmail.com/sportsbar-etl-proj/2_dim_data_process/silver/silver_customer_data_processing",
    "/Users/lopezjatjat10@gmail.com/sportsbar-etl-proj/2_dim_data_process/gold/gold_customer_data_processing"
]


for nb in customer_notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
